# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
dataset = pd.read_csv('DecisionTrees_titanic.csv')
dataset.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         1       1    0  38.0      1      0  71.2833         0
# 1         1       1    0  35.0      1      0  53.1000         2
# 2         0       1    1  54.0      0      0  51.8625         2
# 3         1       3    0   4.0      1      1  16.7000         2
# 4         1       1    0  58.0      0      0  26.5500         2

# %% [markdown]
# X özelliklerine ve y hedeflerine göre veri kümeleri sonrasında veri kümeleri eğitim test işlemleri gerçekleştiriliyor.

# %%
x = dataset.drop('Survived',axis = 1)
y = dataset.loc[:,'Survived']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3)

# %%
decisiontree = DecisionTreeClassifier()
randomforest =RandomForestClassifier()

# %%
decisiontree.fit(x_train,y_train)
randomforest.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize = (10,10))
plot_tree(decisiontree,max_depth = 2,feature_names = x.columns, filled =True,impurity =False,rounded =True, precision = 1)
# Out:
# [Text(0.4444444444444444, 0.875, 'Sex <= 0.5\nsamples = 128\nvalue = [40, 88]'),
#  Text(0.2222222222222222, 0.625, 'Age <= 3.0\nsamples = 58\nvalue = [4, 54]'),
#  Text(0.1111111111111111, 0.375, 'samples = 2\nvalue = [2, 0]'),
#  Text(0.3333333333333333, 0.375, 'Age <= 49.0\nsamples = 56\nvalue = [2, 54]'),
#  Text(0.2222222222222222, 0.125, '\n  (...)  \n'),
#  Text(0.4444444444444444, 0.125, '\n  (...)  \n'),
#  Text(0.6666666666666666, 0.625, 'Age <= 17.5\nsamples = 70\nvalue = [36, 34]'),
#  Text(0.5555555555555556, 0.375, 'samples = 7\nvalue = [0, 7]'),
#  Text(0.7777777777777778, 0.375, 'Age <= 53.0\nsamples = 63\nvalue = [36, 27]'),
#  Text(0.6666666666666666, 0.125, '\n  (...)  \n'),
#  Text(0.8888888888888888, 0.125, '\n  (...)  \n')]

# %% [markdown]
# max_depth = 2 -> 3 katman gösterildi

# %%
fig = plt.figure(figsize = (10,10))
plot_tree(decisiontree,max_depth = 2,feature_names = x.columns, filled =True,impurity =False,rounded =True, precision = 1)
plt.show()

# %%
decisiontree_pred =decisiontree.predict(x_test)
randomforest_pred =randomforest.predict(x_test)

# %%
print(classification_report(y_test,decisiontree_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.35      0.42        20
#            1       0.69      0.83      0.75        35
#
#     accuracy                           0.65        55
#    macro avg       0.61      0.59      0.59        55
# weighted avg       0.64      0.65      0.63        55

# %%
print(classification_report(y_test,randomforest_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.45      0.58        20
#            1       0.75      0.94      0.84        35
#
#     accuracy                           0.76        55
#    macro avg       0.78      0.70      0.71        55
# weighted avg       0.77      0.76      0.74        55
